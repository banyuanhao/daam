# %%
import json
import matplotlib.pyplot as plt
import numpy as np

with open('../wrapupdata/ratio_noun.json') as f:
    data = json.load(f)
    
base = np.ones(31)

fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
for i,dic in enumerate(data):
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ax.plot(ratio)
    ax.set_xlabel('Steps')
    ax.set_ylabel('Ratio')
fig.show()
fig.savefig('when_ratio_noun.png')

    
import numpy as np

with open('../wrapupdata/ratio_adj.json') as f:
    data = json.load(f)
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(10, linestyle='--', color='black', linewidth=2)
for dic in data:
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ax.plot(ratio)
    ax.set_xlabel('Steps')
    ax.set_ylabel('Ratio')
fig.show()
fig.savefig('when_ratio_adj.png')
