# %%
choices = ['noun_removal', 'noun_style', 'noun_general', 'noun_abstract',
                             'adj_noun','adj_noun_0','adj_noun_1',
                             'adj_general','adj_specific',
                             'steps_adj','steps_noun']
path = '/home/banyh2000/diffusion/daam/wrapupdata/rebuttal/generalize'

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

choice = 'noun_style'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
ratios = []
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios.append(ratio)
ratios = np.array(ratios)
rank = ratios[:,-1]/ratios[:,6]
# sort ratios by rank
ratios = ratios[np.argsort(rank,)]
ratios = ratios[100:]

ratios = np.mean(ratios,axis=0)
ax.plot(ratios)
ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.set_title(f'{choice}')
fig.show()
fig.savefig('when_ratio_noun.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

choice = 'noun_style'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
ratios = []
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios.append(ratio)
ratios = np.array(ratios)
rank = ratios[:,-1]/ratios[:,6]
# sort ratios by rank
ratios = ratios[np.argsort(rank,)]
ratios = ratios[100:]

ratios = np.mean(ratios,axis=0)
ax.plot(ratios)
ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.set_title(f'{choice}')
fig.show()
fig.savefig('when_ratio_noun.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

choice = 'noun_removal'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
ratios = []
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios.append(ratio)
ratios = np.array(ratios)
rank = ratios[:,-1]/ratios[:,6]
# sort ratios by rank
ratios = ratios[np.argsort(rank,)]
ratios = ratios[20:100]

ratios = np.mean(ratios,axis=0)
ax.plot(ratios)
ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.set_title(f'{choice}')
fig.show()
fig.savefig('when_ratio_noun.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

choice = 'adj_general'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
ratios = []
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios.append(ratio)
ratios = np.array(ratios)
rank = ratios[:,20]/ratios[:,-1]
# sort ratios by rank
ratios = ratios[np.argsort(rank,)]
ratios = ratios[:200]

ratios = np.mean(ratios,axis=0)
ax.plot(ratios)
ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.set_title(f'{choice}')
fig.show()
fig.savefig('when_ratio_noun.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

choice = 'adj_specific'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
ratios = []
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios.append(ratio)
ratios = np.array(ratios)
rank = ratios[:,0]/ratios[:,-1]
# sort ratios by rank
ratios = ratios[np.argsort(rank,)]
ratios = ratios[:80]

ratios = np.mean(ratios,axis=0)
ax.plot(ratios)
ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.set_title(f'{choice}')
fig.show()
fig.savefig('when_ratio_noun.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

for choice in choices:
    with open(f'{path}/{choice}.json') as f:
        data = json.load(f)
        
    base = np.ones(31)
    negative_list = []
    fig, ax = plt.subplots()
    ax.grid(True)
    # plot base as dotted line
    ax.plot(base,linestyle='--', linewidth=2, color='black' )
    ax.axvline(5, linestyle='--', color='black', linewidth=2)
    ratios = []
    for i,dic in enumerate(data):
        negative_list.append(dic['negative_prompt'])
        ratio = np.mean(np.array(dic['ratio']),axis=0)
        ratios.append(ratio)
    ratios = np.array(ratios)
    ratios = np.mean(ratios,axis=0)
    ax.plot(ratios)
    ax.set_xlabel('Steps')
    ax.set_ylabel('Ratio')
    ax.set_title(f'{choice}')
    fig.show()
    fig.savefig('when_ratio_noun.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 21
#      19     ratio = np.mean(np.array(dic['ratio']),axis=0)
#      20     ratios.append(ratio)
# ---> 21 ratios = np.array(ratios)
#      22 ratios = np.mean(ratios,axis=0)
#      23 ax.plot(ratios)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (57,) + inhomogeneous part.

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

with open('../wrapupdata/ratio_noun_spec.json') as f:
    data = json.load(f)
    
base = np.ones(31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
for i,dic in enumerate(data):
    print(dic['negative_prompt'])
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ax.plot(ratio)
    ax.set_xlabel('Steps')
    ax.set_ylabel('Ratio')
fig.show()
# fig.savefig('when_ratio_noun.png')
# Out:
# flowers
# flowers
# car
# table
# people
# tree
# streetlights
# people
# moon
# boats
# cow
# cars
# animals
# television
# buildings
# people
# city lights
# bridges
# graffiti
# roads

# %%
    
import numpy as np
import json
import matplotlib.pyplot as plt
base = np.ones(31)
with open('../wrapupdata/ratio_adj_spec.json') as f:
    data = json.load(f)
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(10, linestyle='--', color='black', linewidth=2)
for dic in data:
    if dic['negative_prompt'] in negative_list:
        continue
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ax.plot(ratio)
    ax.set_xlabel('Steps')
    ax.set_ylabel('Ratio')
fig.show()
fig.savefig('when_ratio_adj.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
steps = [20, 30, 40, 50, 60, 70, 80]


choice = 'steps_adj'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
xval = np.linspace(0,1,31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(xval, base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5/30, linestyle='--', color='black', linewidth=2)
ratios = {20:[],30:[],40:[],50:[],60:[],70:[],80:[]}
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios[dic['steps']].append(ratio)

for key, value in ratios.items():
    ratios[key] = np.mean(value,axis=0)
    lens = len(ratios[key])
    xval = np.linspace(0,1,lens)
    ax.plot(xval, ratios[key],label=f'{key}')


ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.legend()
ax.set_title(f'{choice}')
fig.show()
# fig.savefig('when_ratio_noun.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
steps = [20, 30, 40, 50, 60, 70, 80]


choice = 'steps_noun'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
xval = np.linspace(0,1,31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(xval, base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5/30, linestyle='--', color='black', linewidth=2)
ratios = {20:[],30:[],40:[],50:[],60:[],70:[],80:[]}
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios[dic['steps']].append(ratio)

for key, value in ratios.items():
    ratios[key] = np.mean(value,axis=0)
    lens = len(ratios[key])
    xval = np.linspace(0,1,lens)
    ax.plot(xval, ratios[key],label=f'{key}')


ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.legend()
ax.set_title(f'{choice}')
fig.show()
# fig.savefig('when_ratio_noun.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

choice = 'adj_noun'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
ratios = []
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios.append(ratio)
ratios = np.array(ratios)
rank = ratios[:,-1]/ratios[:,6]
# sort ratios by rank
ratios = ratios[np.argsort(rank,)]
ratios = ratios[100:]

ratios = np.mean(ratios,axis=0)
ax.plot(ratios)
ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.set_title(f'{choice}')
fig.show()
fig.savefig('when_ratio_noun.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

choice = 'adj_noun_0'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
ratios = []
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios.append(ratio)
ratios = np.array(ratios)
rank = ratios[:,-1]/ratios[:,6]
# sort ratios by rank
ratios = ratios[np.argsort(rank,)]
ratios = ratios[100:]

ratios = np.mean(ratios,axis=0)
ax.plot(ratios)
ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.set_title(f'{choice}')
fig.show()
fig.savefig('when_ratio_noun.png')

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

choice = 'adj_noun_1'
with open(f'{path}/{choice}.json') as f:
    data = json.load(f)
    
base = np.ones(31)
negative_list = []
fig, ax = plt.subplots()
ax.grid(True)
# plot base as dotted line
ax.plot(base,linestyle='--', linewidth=2, color='black' )
ax.axvline(5, linestyle='--', color='black', linewidth=2)
ratios = []
for i,dic in enumerate(data):
    negative_list.append(dic['negative_prompt'])
    ratio = np.mean(np.array(dic['ratio']),axis=0)
    ratios.append(ratio)
ratios = np.array(ratios)
rank = ratios[:,-1]/ratios[:,6]
# sort ratios by rank
ratios = ratios[np.argsort(rank,)]
ratios = ratios[100:]

ratios = np.mean(ratios,axis=0)
ax.plot(ratios)
ax.set_xlabel('Steps')
ax.set_ylabel('Ratio')
ax.set_title(f'{choice}')
fig.show()
fig.savefig('when_ratio_noun.png')
