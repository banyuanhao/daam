# %%
from models.diffuserpipeline import StableDiffusionPipelineForNegativePrompts
import torch
from daam.utils import set_seed
from matplotlib import pyplot as plt
model_id = 'stabilityai/stable-diffusion-2-base'
device = 'cuda'
pipe = StableDiffusionPipelineForNegativePrompts.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "professional office woman"
negative_prompt = "glasses"
seed = 8577767
steps = 30
words = "n:glasses"

fig, axs = plt.subplots(1, 2, figsize=(20, 10))
for ax in axs:
    ax.axis('off')
fig.tight_layout()
with torch.cuda.amp.autocast(dtype=torch.float16), torch.no_grad():
    out = pipe.inject(prompt, negative_prompt=negative_prompt, num_inference_steps=steps, generator=set_seed(seed),inject_step=[4],inject_guidance = 10)
    axs[1].imshow(out.images[0])
    out = pipe.inject(prompt, negative_prompt=negative_prompt, num_inference_steps=steps, generator=set_seed(seed),inject_step=[5],inject_guidance = -10)
    axs[0].imshow(out.images[0])
# Out:
# Keyword arguments {'use_auth_token': True} are not expected by StableDiffusionPipelineForNegativePrompts and will be ignored.
# Loading pipeline components...: 100%|██████████| 6/6 [00:00<00:00,  8.00it/s]

# %%
from models.diffuserpipeline import StableDiffusionPipelineForNegativePrompts
import torch
from daam.utils import set_seed
from matplotlib import pyplot as plt
model_id = 'stabilityai/stable-diffusion-2-base'
device = 'cuda'
pipe = StableDiffusionPipelineForNegativePrompts.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "professional office woman"
negative_prompt = "glasses"
seed = 51473
steps = 30
words = "n:glasses"

with torch.cuda.amp.autocast(dtype=torch.float16), torch.no_grad():
    out = pipe.inject(prompt, negative_prompt=negative_prompt, num_inference_steps=steps, generator=set_seed(seed),inject_step=[5,6],inject_guidance = -25)
    
plt.imshow(out.images[0])
# Out:
# Keyword arguments {'use_auth_token': True} are not expected by StableDiffusionPipelineForNegativePrompts and will be ignored.
# Loading pipeline components...: 100%|██████████| 6/6 [00:00<00:00, 14.46it/s]

# %%
from models.diffuserpipeline import StableDiffusionPipelineForNegativePrompts
import torch
from daam.utils import set_seed
from matplotlib import pyplot as plt
model_id = 'stabilityai/stable-diffusion-2-base'
device = 'cuda'
pipe = StableDiffusionPipelineForNegativePrompts.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "professional office woman"
negative_prompt = "glasses"
seed = 5133
steps = 30
words = "n:glasses"

with torch.cuda.amp.autocast(dtype=torch.float16), torch.no_grad():
    out = pipe.inject(prompt, negative_prompt=negative_prompt, num_inference_steps=steps, generator=set_seed(seed),inject_step=[4],inject_guidance = 10)

plt.imshow(out.images[0])
# Out:
# Keyword arguments {'use_auth_token': True} are not expected by StableDiffusionPipelineForNegativePrompts and will be ignored.
# Loading pipeline components...: 100%|██████████| 6/6 [00:00<00:00,  9.16it/s]

# %%
from models.diffuserpipeline import StableDiffusionPipelineForNegativePrompts
import torch
from daam.utils import set_seed
from matplotlib import pyplot as plt
model_id = 'stabilityai/stable-diffusion-2-base'
device = 'cuda'
pipe = StableDiffusionPipelineForNegativePrompts.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "professional office woman"
negative_prompt = "glasses"
seed = 2123
steps = 30

with torch.cuda.amp.autocast(dtype=torch.float16), torch.no_grad():
    out = pipe.inject(prompt, negative_prompt=negative_prompt, num_inference_steps=steps, generator=set_seed(seed),inject_step=[6],inject_guidance = -30)

plt.imshow(out.images[0])
# Out:
# Keyword arguments {'use_auth_token': True} are not expected by StableDiffusionPipelineForNegativePrompts and will be ignored.
# Loading pipeline components...: 100%|██████████| 6/6 [00:00<00:00,  7.60it/s]

# %%
from models.diffuserpipeline import StableDiffusionPipelineForNegativePrompts
import torch
from daam.utils import set_seed
from matplotlib import pyplot as plt
model_id = 'stabilityai/stable-diffusion-2-base'
device = 'cuda'
pipe = StableDiffusionPipelineForNegativePrompts.from_pretrained(model_id, use_auth_token=True)
pipe = pipe.to(device)

prompt = "professional office woman"
negative_prompt = "glasses"
seed = 231241
steps = 30

with torch.cuda.amp.autocast(dtype=torch.float16), torch.no_grad():
    out = pipe.inject(prompt, negative_prompt=negative_prompt, num_inference_steps=steps, generator=set_seed(seed),inject_step=[5],inject_guidance = -30)

plt.imshow(out.images[0])
# Out:
# Keyword arguments {'use_auth_token': True} are not expected by StableDiffusionPipelineForNegativePrompts and will be ignored.
# Loading pipeline components...: 100%|██████████| 6/6 [00:00<00:00,  7.01it/s]
